# %% [markdown]
# <a href="https://colab.research.google.com/github/welting82/AIclass/blob/main/Classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.datasets import load_iris
iris = load_iris()
df = pd.DataFrame(iris["data"],columns=iris["feature_names"])
df.to_csv("iris.csv",encoding = "utf-8", index = False)
df["ans"] = iris["target"]
df
# Out:
#      sepal length (cm)  sepal width (cm)  ...  petal width (cm)  ans
# 0                  5.1               3.5  ...               0.2    0
# 1                  4.9               3.0  ...               0.2    0
# 2                  4.7               3.2  ...               0.2    0
# 3                  4.6               3.1  ...               0.2    0
# 4                  5.0               3.6  ...               0.2    0
# ..                 ...               ...  ...               ...  ...
# 145                6.7               3.0  ...               2.3    2
# 146                6.3               2.5  ...               1.9    2
# 147                6.5               3.0  ...               2.0    2
# 148                6.2               3.4  ...               2.3    2
# 149                5.9               3.0  ...               1.8    2
#
# [150 rows x 5 columns]

# %%
import numpy as np
y = np.array(df["ans"])
x = np.array(df.drop(["ans"], axis = 1))

# %%
from sklearn.model_selection import train_test_split
[x_train, x_test, y_train, y_test] = train_test_split(x,y,test_size = 0.1)

# %%
from sklearn.tree import DecisionTreeClassifier
clf = DecisionTreeClassifier()
clf.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
import matplotlib.pyplot as plt
from sklearn.tree import plot_tree
plt.figure(figsize = (14,14))
plot_tree(clf,feature_names=iris["feature_names"],
          class_names=iris["target_names"],filled=True)
# Out:
# [Text(390.6, 697.62, 'petal width (cm) <= 0.8\ngini = 0.666\nsamples = 135\nvalue = [45, 47, 43]\nclass = versicolor'),
#  Text(330.50769230769237, 570.78, 'gini = 0.0\nsamples = 45\nvalue = [45, 0, 0]\nclass = setosa'),
#  Text(450.69230769230774, 570.78, 'petal width (cm) <= 1.75\ngini = 0.499\nsamples = 90\nvalue = [0, 47, 43]\nclass = versicolor'),
#  Text(240.3692307692308, 443.94, 'petal length (cm) <= 4.95\ngini = 0.177\nsamples = 51\nvalue = [0, 46, 5]\nclass = versicolor'),
#  Text(120.1846153846154, 317.1, 'petal width (cm) <= 1.65\ngini = 0.043\nsamples = 45\nvalue = [0, 44, 1]\nclass = versicolor'),
#  Text(60.0923076923077, 190.26, 'gini = 0.0\nsamples = 44\nvalue = [0, 44, 0]\nclass = versicolor'),
#  Text(180.27692307692308, 190.26, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]\nclass = virginica'),
#  Text(360.55384615384617, 317.1, 'petal width (cm) <= 1.55\ngini = 0.444\nsamples = 6\nvalue = [0, 2, 4]\nclass = virginica'),
#  Text(300.4615384615385, 190.26, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3]\nclass = virginica'),
#  Text(420.6461538461539, 190.26, 'sepal length (cm) <= 6.95\ngini = 0.444\nsamples = 3\nvalue = [0, 2, 1]\nclass = versicolor'),
#  Text(360.55384615384617, 63.42000000000007, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0]\nclass = versicolor'),
#  Text(480.7384615384616, 63.42000000000007, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]\nclass = virginica'),
#  Text(661.0153846153847, 443.94, 'petal length (cm) <= 4.85\ngini = 0.05\nsamples = 39\nvalue = [0, 1, 38]\nclass = virginica'),
#  Text(600.923076923077, 317.1, 'sepal width (cm) <= 3.1\ngini = 0.444\nsamples = 3\nvalue = [0, 1, 2]\nclass = virginica'),
#  Text(540.8307692307693, 190.26, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2]\nclass = virginica'),
#  Text(661.0153846153847, 190.26, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]\nclass = versicolor'),
#  Text(721.1076923076923, 317.1, 'gini = 0.0\nsamples = 36\nvalue = [0, 0, 36]\nclass = virginica')]
